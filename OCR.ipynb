# %%
cd Dataweav_Assignment
# Out:
# /home/sanyam/Documents/Dataweav_Assignment

# %%
import cv2
import  matplotlib.pyplot as plt 
# %matplotlib inline

# %%
os.listdir()
# Out:
# ['Problem2', 'Problem3', 'Problem1']

# %%
import scipy.misc as ms

# %%
arr=ms.imread('Problem1/page-4.jpg')
plt.imshow(arr)
plt.xticks([]),plt.yticks([])
plt.show()

# %%
from PIL import Image
import pytesseract
import argparse
import cv2
import os

# %%
image = cv2.imread('License.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
gray_thresh = cv2.threshold(gray, 0, 255,
		cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

# %%
img=cv2.imread('Problem1/page-4.jpg')
crp=img[275:371,173:1155]
plt.imshow(crp)
cv2.imwrite('fd.jpg',crp)
# Out:
# True

# %%
convert(112,349)
# Out:
# (370.6426426426426, 1154.9489489489488)

# %%
gray__blur=cv2.medianBlur(gray, 3)

# %%
cv2.imwrite('ocr_th.png', gray_thresh)
cv2.imwrite('ocr_blur.png',gray__blur)
# Out:
# True

# %%
q=Image.open('Problem1/page-4.jpg')
w,h=q.size
print(w,h)
# Out:
# 3306 4672

# %%
Image.open('Problem1/page-8.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=3306x4678 at 0x7FD0AC45ABA8>

# %%
text=pytesseract.image_to_string(Image.open('fd.jpg'))

# %%
text
# Out:
# '91 ‘ PKK2973329'

# %%
def convert(w,h):
    W=(3306/999)*w
    H=(3306/999)*h
    return W,H

# %%
convert(999,1413)
# Out:
# (3306.0, 4676.054054054054)

# %%
cv2.imread('')
